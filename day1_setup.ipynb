# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

print("Python, Pandas, NumPy, and scikit-learn are ready!")
# Out:
# Python, Pandas, NumPy, and scikit-learn are ready!
